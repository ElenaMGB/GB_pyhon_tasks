# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaMGB/GB_python_tasks/blob/main/GB_Python_dz10_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Урок 10. Построение графиков

# Задача: В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1
# столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?

import pandas as pd
import random

lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
data.shape
print(data)
# Out:
#    whoAmI
# 0   robot
# 1   human
# 2   human
# 3   human
# 4   robot
# 5   robot
# 6   human
# 7   robot
# 8   human
# 9   robot
# 10  human
# 11  robot
# 12  human
# 13  human
# 14  robot
# 15  robot
# 16  robot
# 17  robot
# 18  human
# 19  human

# %%
#добавляем столбцы в one hot кодировке
data['human'] = data['whoAmI'].apply(lambda x: 0 if x=='robot' else 1)
data['robot'] = data['whoAmI'].apply(lambda x: 1 if x=='robot' else 0)
print(data)
# Out:
#    whoAmI  human  robot
# 0   robot      0      1
# 1   human      1      0
# 2   human      1      0
# 3   human      1      0
# 4   robot      0      1
# 5   robot      0      1
# 6   human      1      0
# 7   robot      0      1
# 8   human      1      0
# 9   robot      0      1
# 10  human      1      0
# 11  robot      0      1
# 12  human      1      0
# 13  human      1      0
# 14  robot      0      1
# 15  robot      0      1
# 16  robot      0      1
# 17  robot      0      1
# 18  human      1      0
# 19  human      1      0

# %%
#проверка
pd.get_dummies(data)
# Out:
#     human  robot  whoAmI_human  whoAmI_robot
# 0       0      1         False          True
# 1       1      0          True         False
# 2       1      0          True         False
# 3       1      0          True         False
# 4       0      1         False          True
# 5       0      1         False          True
# 6       1      0          True         False
# 7       0      1         False          True
# 8       1      0          True         False
# 9       0      1         False          True
# 10      1      0          True         False
# 11      0      1         False          True
# 12      1      0          True         False
# 13      1      0          True         False
# 14      0      1         False          True
# 15      0      1         False          True
# 16      0      1         False          True
# 17      0      1         False          True
# 18      1      0          True         False
# 19      1      0          True         False
